# %%
#!jupyter nbconvert --to script #1.ipynb

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
pd.set_option('display.max_rows', 1000)

# %%
bene = pd.read_csv("Train_Beneficiarydata-1542865627584.csv")
inpat = pd.read_csv("Train_Inpatientdata-1542865627584.csv")
outpat = pd.read_csv("Train_Outpatientdata-1542865627584.csv")
train_classification = pd.read_csv("Train-1542865627584.csv")

# %%
#Train - bene
print(bene.head(1))
print(bene.shape)
print(bene.dtypes)
print(bene.isnull().sum())

# %%
#Train - in patients
print(inpat.head(1))
print(inpat.shape)
print(inpat.dtypes)
print(inpat.isnull().sum())

# %%
#Train - Outpatients
print(outpat.head(1))
print(outpat.shape)
print(outpat.dtypes)
print(outpat.isnull().sum())

# %%
# train_classification 
print(train_classification.head(1))
print(train_classification.shape)
print(train_classification.dtypes)
print(train_classification.isnull().sum())

# %%
inpat_bene = pd.merge(inpat, bene, left_on = 'BeneID',right_on = 'BeneID', how = 'left')

# %%
outpat_bene = pd.merge(outpat, bene, left_on = 'BeneID',right_on = 'BeneID', how = 'left')

# %%
train = pd.concat([inpat_bene, outpat_bene])

# %%
train['DOB'] = pd.to_datetime(train['DOB'])
train['DOD'] = pd.to_datetime(train['DOD'])
train['ClaimEndDt'] = pd.to_datetime(train['ClaimEndDt'])
train['ClaimStartDt'] = pd.to_datetime(train['ClaimStartDt'])
train['AdmissionDt'] = pd.to_datetime(train['AdmissionDt'])
train['DischargeDt'] = pd.to_datetime(train['DischargeDt'])

# %%
#Preprocessing for groupby
train['deceased_sum'] = [1 if pd.isnull(x) else 0 for x in train['DOD']]
train['age'] = ((train['ClaimStartDt'] - train['DOB'])/np.timedelta64(1,'Y')).apply(np.floor)
train['Gender'][train['Gender'] == 2] = 0
train['No_days_admitted'] = (train['DischargeDt']) - (train['AdmissionDt'])
train['No_days_admitted'] = train['No_days_admitted']/np.timedelta64(1,'D')
train['No_days_admitted'][train['No_days_admitted'].isnull()==True]=1
train['No_days_ClaimProcessing'] = (train['ClaimEndDt']-train['ClaimStartDt'])
train['No_days_ClaimProcessing'] = train['No_days_ClaimProcessing']/np.timedelta64(1,'D')
train['RenalDiseaseIndicator'].unique()
train['RenalDiseaseIndicator'][train['RenalDiseaseIndicator'] == 'Y'] = 1

# %%
def series_mode(x):
    value = x.mode()
    if len(value)>0:
        return x.mode()[0]
    else:
        raise Exception(value)

# %%
def series_median(x):
    return x.median()

# %%
def series_sum(x):
    return x.sum()

# %%
# Grouping by Providers
ee1 = train.groupby('Provider').agg({
    "age":[("age_mode",series_mode),("age_median", series_median)],
    "deceased_sum":[("deceased_sum",series_sum)],
    "Gender":[("Gender_mode", series_mode)],
    "Race":[("Race_mode", series_mode)],
    "State":[("State_mode", series_mode)],
    "County":[("County_mode", series_mode)],
    "No_days_admitted":[("No_days_admitted_median", series_median), ("No_days_admitted_mode", series_mode)],
    "No_days_ClaimProcessing":[("No_days_ClaimProcessing_median", series_median), ("No_days_ClaimProcessing_mode", series_mode)],
    "AttendingPhysician":[("AttendingPhysician_mode", series_mode)],
    "RenalDiseaseIndicator":[("RenalDiseaseIndicator_mode",series_mode)],
    "ChronicCond_Alzheimer":[("ChronicCond_Alzheimer_median", series_median), ("ChronicCond_Alzheimer_mode", series_mode)],
    "ChronicCond_Cancer":[("ChronicCond_Cancer_median", series_median), ("ChronicCond_Cancer_mode", series_mode)],
    "ChronicCond_Depression":[("ChronicCond_Depression_median", series_median), ("ChronicCond_Depression_mode", series_mode)],
    "ChronicCond_Diabetes":[("ChronicCond_Diabetes_median", series_median), ("ChronicCond_Diabetes_mode", series_mode)],
    "ChronicCond_Heartfailure":[("ChronicCond_Heartfailure_median", series_median), ("ChronicCond_Heartfailure_mode", series_mode)],
    "ChronicCond_IschemicHeart":[("ChronicCond_IschemicHeart_median", series_median), ("ChronicCond_IschemicHeart_mode", series_mode)],
    "ChronicCond_KidneyDisease":[("ChronicCond_KidneyDisease_median", series_median), ("ChronicCond_KidneyDisease_mode", series_mode)],
    "ChronicCond_ObstrPulmonary":[("ChronicCond_ObstrPulmonary_median", series_median), ("ChronicCond_ObstrPulmonary_mode", series_mode)],
    "ChronicCond_Osteoporasis":[("ChronicCond_Osteoporasis_median", series_median), ("ChronicCond_Osteoporasis_mode", series_mode)],
    "ChronicCond_rheumatoidarthritis":[("ChronicCond_rheumatoidarthritis_median", series_median), ("ChronicCond_rheumatoidarthritis_mode", series_mode)],
    "ChronicCond_stroke":[("ChronicCond_stroke_median", series_median), ("ChronicCond_stroke_mode", series_mode)],
    "NoOfMonths_PartACov":[("NoOfMonths_PartACov_median", series_median), ("NoOfMonths_PartACov_mode", series_mode)],
    "NoOfMonths_PartBCov":[("NoOfMonths_PartBCov_median", series_median), ("NoOfMonths_PartBCov_mode", series_mode)],
    "InscClaimAmtReimbursed":[("InscClaimAmtReimbursed_sum", series_sum), ("InscClaimAmtReimbursed_median", series_median)],
    "OPAnnualDeductibleAmt":[("OPAnnualDeductibleAmt_sum", series_sum), ("OPAnnualDeductibleAmt_median", series_median)],
    "OPAnnualReimbursementAmt":[("OPAnnualReimbursementAmt_sum", series_sum), ("OPAnnualReimbursementAmt_median", series_median)],
    "IPAnnualDeductibleAmt":[("IPAnnualDeductibleAmt_sum", series_sum), ("IPAnnualDeductibleAmt_median", series_median)],
    "IPAnnualReimbursementAmt":[("IPAnnualReimbursementAmt_sum", series_sum), ("IPAnnualReimbursementAmt_median", series_median)],
    "DeductibleAmtPaid":[("DeductibleAmtPaid_sum", series_sum), ("DeductibleAmtPaid_median", series_median)]
})


ee1.columns = ee1.columns.droplevel()

#For OperatingPhysician
OperatingPhysician_mode=pd.DataFrame(train.groupby(['Provider'])["OperatingPhysician"].apply(lambda x: list(x.mode())))
OperatingPhysician_mode['Provider']=OperatingPhysician_mode.index
OperatingPhysician_mode=OperatingPhysician_mode.reset_index(drop=True)
OperatingPhysician_mode.columns=["OperatingPhysician_mode", "Provider"]
OperatingPhysician_mode["Provider"]=OperatingPhysician_mode["Provider"].astype(object)
ee1=ee1.merge(OperatingPhysician_mode, on='Provider')


#For OtherPhysician
OtherPhysician_mode=pd.DataFrame(train.groupby(['Provider'])["OtherPhysician"].apply(lambda x: list(x.mode())))
OtherPhysician_mode['Provider']=OtherPhysician_mode.index
OtherPhysician_mode=OtherPhysician_mode.reset_index(drop=True)
OtherPhysician_mode.columns=["OtherPhysician_mode", "Provider"]
OtherPhysician_mode["Provider"]=OtherPhysician_mode["Provider"].astype(object)
ee1=ee1.merge(OtherPhysician_mode, on='Provider')


#no_of_service_provided
no_of_service_provided = pd.DataFrame(train['Provider'].value_counts())
no_of_service_provided.columns = ['no_of_service_provided']
no_of_service_provided['Provider'] = no_of_service_provided.index
ee1=ee1.merge(no_of_service_provided, on='Provider')

# %%
ee1.head().transpose()
# Out:
#                                                                                         0  \
# Provider                                                                         PRV51001
# age_mode                                                                               69
# age_median                                                                             79
# deceased_sum                                                                           25
# Gender_mode                                                                             0
# Race_mode                                                                               1
# State_mode                                                                              1
# County_mode                                                                           440
# No_days_admitted_median                                                                 1
# No_days_admitted_mode                                                                   1
# No_days_ClaimProcessing_median                                                          0
# No_days_ClaimProcessing_mode                                                            0
# AttendingPhysician_mode                                                         PHY350459
# RenalDiseaseIndicator_mode                                                              0
# ChronicCond_Alzheimer_median                                                            1
# ChronicCond_Alzheimer_mode                                                              1
# ChronicCond_Cancer_median                                                               2
# ChronicCond_Cancer_mode                                                                 2
# ChronicCond_Depression_median                                                           2
# ChronicCond_Depression_mode                                                             2
# ChronicCond_Diabetes_median                                                             1
# ChronicCond_Diabetes_mode                                                               1
# ChronicCond_Heartfailure_median                                                         1
# ChronicCond_Heartfailure_mode                                                           1
# ChronicCond_IschemicHeart_median                                                        1
# ChronicCond_IschemicHeart_mode                                                          1
# ChronicCond_KidneyDisease_median                                                        1
# ChronicCond_KidneyDisease_mode                                                          1
# ChronicCond_ObstrPulmonary_median                                                       2
# ChronicCond_ObstrPulmonary_mode                                                         2
# ChronicCond_Osteoporasis_median                                                         2
# ChronicCond_Osteoporasis_mode                                                           2
# ChronicCond_rheumatoidarthritis_median                                                  2
# ChronicCond_rheumatoidarthritis_mode                                                    2
# ChronicCond_stroke_median                                                               2
# ChronicCond_stroke_mode                                                                 2
# NoOfMonths_PartACov_median                                                             12
# NoOfMonths_PartACov_mode                                                               12
# NoOfMonths_PartBCov_median                                                             12
# NoOfMonths_PartBCov_mode                                                               12
# InscClaimAmtReimbursed_sum                                                         104640
# InscClaimAmtReimbursed_median                                                         400
# OPAnnualDeductibleAmt_sum                                                           11598
# OPAnnualDeductibleAmt_median                                                          150
# OPAnnualReimbursementAmt_sum                                                        65380
# OPAnnualReimbursementAmt_median                                                      1590
# IPAnnualDeductibleAmt_sum                                                           22428
# IPAnnualDeductibleAmt_median                                                            0
# IPAnnualReimbursementAmt_sum                                                       440150
# IPAnnualReimbursementAmt_median                                                         0
# DeductibleAmtPaid_sum                                                                5340
# DeductibleAmtPaid_median                                                                0
# OperatingPhysician_mode                 [PHY329739, PHY378091, PHY392882, PHY394703, P...
# OtherPhysician_mode                                                [PHY350459, PHY402512]
# no_of_service_provided                                                                 25
#
#                                                                         1  \
# Provider                                                         PRV51003
# age_mode                                                               69
# age_median                                                             71
# deceased_sum                                                          131
# Gender_mode                                                             0
# Race_mode                                                               1
# State_mode                                                              1
# County_mode                                                           340
# No_days_admitted_median                                                 1
# No_days_admitted_mode                                                   1
# No_days_ClaimProcessing_median                                        1.5
# No_days_ClaimProcessing_mode                                            0
# AttendingPhysician_mode                                         PHY364445
# RenalDiseaseIndicator_mode                                              0
# ChronicCond_Alzheimer_median                                            2
# ChronicCond_Alzheimer_mode                                              2
# ChronicCond_Cancer_median                                               2
# ChronicCond_Cancer_mode                                                 2
# ChronicCond_Depression_median                                           2
# ChronicCond_Depression_mode                                             2
# ChronicCond_Diabetes_median                                             1
# ChronicCond_Diabetes_mode                                               1
# ChronicCond_Heartfailure_median                                         1
# ChronicCond_Heartfailure_mode                                           1
# ChronicCond_IschemicHeart_median                                        1
# ChronicCond_IschemicHeart_mode                                          1
# ChronicCond_KidneyDisease_median                                        2
# ChronicCond_KidneyDisease_mode                                          2
# ChronicCond_ObstrPulmonary_median                                       2
# ChronicCond_ObstrPulmonary_mode                                         2
# ChronicCond_Osteoporasis_median                                         2
# ChronicCond_Osteoporasis_mode                                           2
# ChronicCond_rheumatoidarthritis_median                                  2
# ChronicCond_rheumatoidarthritis_mode                                    2
# ChronicCond_stroke_median                                               2
# ChronicCond_stroke_mode                                                 2
# NoOfMonths_PartACov_median                                             12
# NoOfMonths_PartACov_mode                                               12
# NoOfMonths_PartBCov_median                                             12
# NoOfMonths_PartBCov_mode                                               12
# InscClaimAmtReimbursed_sum                                         605670
# InscClaimAmtReimbursed_median                                        1750
# OPAnnualDeductibleAmt_sum                                           97300
# OPAnnualDeductibleAmt_median                                          210
# OPAnnualReimbursementAmt_sum                                       353520
# OPAnnualReimbursementAmt_median                                      1235
# IPAnnualDeductibleAmt_sum                                          122948
# IPAnnualDeductibleAmt_median                                         1068
# IPAnnualReimbursementAmt_sum                                       999000
# IPAnnualReimbursementAmt_median                                      4580
# DeductibleAmtPaid_sum                                               66286
# DeductibleAmtPaid_median                                                0
# OperatingPhysician_mode                                       [PHY364445]
# OtherPhysician_mode                     [PHY345349, PHY371660, PHY418784]
# no_of_service_provided                                                132
#
#                                                   2            3            4
# Provider                                   PRV51004     PRV51005     PRV51007
# age_mode                                         72           67           71
# age_median                                       72           70         69.5
# deceased_sum                                    148         1161           71
# Gender_mode                                       0            0            0
# Race_mode                                         1            1            1
# State_mode                                        1            1            1
# County_mode                                     150          620          380
# No_days_admitted_median                           1            1            1
# No_days_admitted_mode                             1            1            1
# No_days_ClaimProcessing_median                    0            0            0
# No_days_ClaimProcessing_mode                      0            0            0
# AttendingPhysician_mode                   PHY394093    PHY342753    PHY380717
# RenalDiseaseIndicator_mode                        0            0            0
# ChronicCond_Alzheimer_median                      2            2            2
# ChronicCond_Alzheimer_mode                        2            2            2
# ChronicCond_Cancer_median                         2            2            2
# ChronicCond_Cancer_mode                           2            2            2
# ChronicCond_Depression_median                     2            2            2
# ChronicCond_Depression_mode                       2            2            2
# ChronicCond_Diabetes_median                       1            1            1
# ChronicCond_Diabetes_mode                         1            1            1
# ChronicCond_Heartfailure_median                   1            1            1
# ChronicCond_Heartfailure_mode                     1            1            1
# ChronicCond_IschemicHeart_median                  1            1            1
# ChronicCond_IschemicHeart_mode                    1            1            1
# ChronicCond_KidneyDisease_median                  2            2            2
# ChronicCond_KidneyDisease_mode                    2            2            2
# ChronicCond_ObstrPulmonary_median                 2            2            2
# ChronicCond_ObstrPulmonary_mode                   2            2            2
# ChronicCond_Osteoporasis_median                   2            2            2
# ChronicCond_Osteoporasis_mode                     2            2            2
# ChronicCond_rheumatoidarthritis_median            2            2            2
# ChronicCond_rheumatoidarthritis_mode              2            2            2
# ChronicCond_stroke_median                         2            2            2
# ChronicCond_stroke_mode                           2            2            2
# NoOfMonths_PartACov_median                       12           12           12
# NoOfMonths_PartACov_mode                         12           12           12
# NoOfMonths_PartBCov_median                       12           12           12
# NoOfMonths_PartBCov_mode                         12           12           12
# InscClaimAmtReimbursed_sum                    52170       280910        33710
# InscClaimAmtReimbursed_median                    70           70           80
# OPAnnualDeductibleAmt_sum                     92790       741323        33820
# OPAnnualDeductibleAmt_median                    380          360          240
# OPAnnualReimbursementAmt_sum                 327040      2457840       124540
# OPAnnualReimbursementAmt_median                1140         1200         1290
# IPAnnualDeductibleAmt_sum                     64808       441724        32040
# IPAnnualDeductibleAmt_median                      0            0            0
# IPAnnualReimbursementAmt_sum                 648430      4221950       219600
# IPAnnualReimbursementAmt_median                   0            0            0
# DeductibleAmtPaid_sum                           310         3700         3264
# DeductibleAmtPaid_median                          0            0            0
# OperatingPhysician_mode                 [PHY342935]  [PHY319039]  [PHY380717]
# OtherPhysician_mode                     [PHY355572]  [PHY342753]  [PHY380717]
# no_of_service_provided                          149         1165           72

# %%
train_df = pd.DataFrame({'Provider': list(train['Provider'].unique())})

# %%
#ee1.columns = ee1.columns.droplevel()
train_df = train_df.merge(ee1, on = 'Provider')

# %%
train_df = pd.merge(train_df, train_classification, left_on = 'Provider', right_on = 'Provider', how = 'inner')

# %%
train_df.head().transpose()
# Out:
#                                                   0                       1  \
# Provider                                   PRV55912                PRV55907
# age_mode                                         67                      81
# age_median                                       75                      75
# deceased_sum                                    105                     242
# Gender_mode                                       0                       0
# Race_mode                                         1                       1
# State_mode                                       39                      39
# County_mode                                     510                     770
# No_days_admitted_median                           2                       1
# No_days_admitted_mode                             1                       1
# No_days_ClaimProcessing_median                    3                       0
# No_days_ClaimProcessing_mode                      0                       0
# AttendingPhysician_mode                   PHY414999               PHY331860
# RenalDiseaseIndicator_mode                        0                       0
# ChronicCond_Alzheimer_median                      2                       2
# ChronicCond_Alzheimer_mode                        2                       2
# ChronicCond_Cancer_median                         2                       2
# ChronicCond_Cancer_mode                           2                       2
# ChronicCond_Depression_median                     2                       2
# ChronicCond_Depression_mode                       2                       2
# ChronicCond_Diabetes_median                       1                       1
# ChronicCond_Diabetes_mode                         1                       1
# ChronicCond_Heartfailure_median                   1                       1
# ChronicCond_Heartfailure_mode                     1                       1
# ChronicCond_IschemicHeart_median                  1                       1
# ChronicCond_IschemicHeart_mode                    1                       1
# ChronicCond_KidneyDisease_median                  1                       2
# ChronicCond_KidneyDisease_mode                    1                       2
# ChronicCond_ObstrPulmonary_median                 2                       2
# ChronicCond_ObstrPulmonary_mode                   2                       2
# ChronicCond_Osteoporasis_median                   2                       2
# ChronicCond_Osteoporasis_mode                     2                       2
# ChronicCond_rheumatoidarthritis_median            2                       2
# ChronicCond_rheumatoidarthritis_mode              2                       2
# ChronicCond_stroke_median                         2                       2
# ChronicCond_stroke_mode                           2                       2
# NoOfMonths_PartACov_median                       12                      12
# NoOfMonths_PartACov_mode                         12                      12
# NoOfMonths_PartBCov_median                       12                      12
# NoOfMonths_PartBCov_mode                         12                      12
# InscClaimAmtReimbursed_sum                   750080                  598180
# InscClaimAmtReimbursed_median                  4000                     100
# OPAnnualDeductibleAmt_sum                     59690                  171700
# OPAnnualDeductibleAmt_median                    300                     420
# OPAnnualReimbursementAmt_sum                 249270                  608230
# OPAnnualReimbursementAmt_median                 900                    1210
# IPAnnualDeductibleAmt_sum                    148908                  204920
# IPAnnualDeductibleAmt_median                   1068                    1068
# IPAnnualReimbursementAmt_sum                1420920                 1946470
# IPAnnualReimbursementAmt_median                8600                    3000
# DeductibleAmtPaid_sum                         64110                   64490
# DeductibleAmtPaid_median                       1068                       0
# OperatingPhysician_mode                 [PHY370861]             [PHY375412]
# OtherPhysician_mode                     [PHY387346]  [PHY347835, PHY348866]
# no_of_service_provided                          107                     243
# PotentialFraud                                  Yes                      No
#
#                                                   2            3            4
# Provider                                   PRV56046     PRV52405     PRV56614
# age_mode                                         69           71           72
# age_median                                       70           71           72
# deceased_sum                                     20           88           26
# Gender_mode                                       0            0            0
# Race_mode                                         1            1            1
# State_mode                                       39            1           45
# County_mode                                     230          340          780
# No_days_admitted_median                           3            1          1.5
# No_days_admitted_mode                             1            1            1
# No_days_ClaimProcessing_median                    3            0            2
# No_days_ClaimProcessing_mode                      0            0            0
# AttendingPhysician_mode                   PHY324689    PHY369659    PHY338104
# RenalDiseaseIndicator_mode                        0            0            0
# ChronicCond_Alzheimer_median                      1            2            2
# ChronicCond_Alzheimer_mode                        1            2            2
# ChronicCond_Cancer_median                         2            2            2
# ChronicCond_Cancer_mode                           2            2            2
# ChronicCond_Depression_median                     1            1            1
# ChronicCond_Depression_mode                       1            1            1
# ChronicCond_Diabetes_median                       1            1            1
# ChronicCond_Diabetes_mode                         1            1            1
# ChronicCond_Heartfailure_median                   1            1            1
# ChronicCond_Heartfailure_mode                     1            1            1
# ChronicCond_IschemicHeart_median                  1            1            1
# ChronicCond_IschemicHeart_mode                    1            1            1
# ChronicCond_KidneyDisease_median                  1            2            1
# ChronicCond_KidneyDisease_mode                    1            2            1
# ChronicCond_ObstrPulmonary_median                 2            2            1
# ChronicCond_ObstrPulmonary_mode                   2            2            1
# ChronicCond_Osteoporasis_median                 1.5            2            2
# ChronicCond_Osteoporasis_mode                     1            2            2
# ChronicCond_rheumatoidarthritis_median            2            2            2
# ChronicCond_rheumatoidarthritis_mode              2            2            2
# ChronicCond_stroke_median                         2            2            2
# ChronicCond_stroke_mode                           2            2            2
# NoOfMonths_PartACov_median                       12           12           12
# NoOfMonths_PartACov_mode                         12           12           12
# NoOfMonths_PartBCov_median                       12           12           12
# NoOfMonths_PartBCov_mode                         12           12           12
# InscClaimAmtReimbursed_sum                   121680       189070       126100
# InscClaimAmtReimbursed_median                  5000          100         2500
# OPAnnualDeductibleAmt_sum                      4730        88310        28700
# OPAnnualDeductibleAmt_median                    185          330          400
# OPAnnualReimbursementAmt_sum                  24050       251730       103960
# OPAnnualReimbursementAmt_median                 700          970          970
# IPAnnualDeductibleAmt_sum                     33632        65148        33108
# IPAnnualDeductibleAmt_median                   1068            0         1068
# IPAnnualReimbursementAmt_sum                 366840       656110       311840
# IPAnnualReimbursementAmt_median                7520            0         5500
# DeductibleAmtPaid_sum                         14952        23606        13884
# DeductibleAmtPaid_median                       1068            0         1068
# OperatingPhysician_mode                 [PHY372395]  [PHY325656]  [PHY398258]
# OtherPhysician_mode                     [PHY324689]  [PHY369659]  [PHY338104]
# no_of_service_provided                           20           89           26
# PotentialFraud                                   No           No           No

# %%
train_df.to_csv('C:/Users/Deepak/Desktop/SB Capstone - 1/data/Processed_Data/Train.csv')
